# %%
import numpy as np
import pandas as pd

import re

# %matplotlib inline

# %%
pd.set_option('display.max_columns', 500)

# %%
df_HC600_HYPERFIRE = pd.read_csv('exifdata_HF2_PRO_COVERT_2.csv')

#Remove Best of Folder

print(len(df_HC600_HYPERFIRE))
df_HC600_HYPERFIRE = df_HC600_HYPERFIRE[~df_HC600_HYPERFIRE['Directory'].str.contains("Best of CoE wildlife photos")]
print(len(df_HC600_HYPERFIRE))

def convertToInt(x):
    h = re.findall(r'\d+', x.split('_')[-1])
    if len(h) == 0:
        print(x)
    return int(h[0])

df_HC600_HYPERFIRE['image_number'] = df_HC600_HYPERFIRE['FileName'].apply(lambda x: convertToInt(x))

# df_HC600_HYPERFIRE['image_number'] = df_HC600_HYPERFIRE['FileName'].apply(lambda x: 
#                                                                           re.findall(r'\d+', x.split('_')[-1])[0])

print(len(df_HC600_HYPERFIRE))

df_ai_results = pd.read_csv('ml_results.csv')
print(len(df_ai_results))
# Out:
# 31411
# 31411
# 31411
# 1203908

# %%
df_HC600_HYPERFIRE['Sequence'].unique()
# Out:
# array(['0 of 0', '1 of 3', '2 of 3', '3 of 3'], dtype=object)

# %%
df_HC600_HYPERFIRE.groupby('Model').size()
# Out:
# Model
# HF2 PRO COVERT    31411
# dtype: int64

# %%
df_HC600_HYPERFIRE[df_HC600_HYPERFIRE.Model == 'HF2 PRO COVERT'].head()
# Out:
#                                           SourceFile  ExifToolVersion  \
# 0  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 1  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 2  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 3  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 4  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
#
#                       FileName  \
# 0  EDALA04HOH1_D8_RCNX0490.JPG
# 1  EDALA04SST3_D1_RCNX0010.JPG
# 2  EDALA04SST3_D1_RCNX0011.JPG
# 3  EDALA04SST3_D1_RCNX0012.JPG
# 4  EDALA04SST3_D1_RCNX0013.JPG
#
#                                            Directory FileSize  \
# 0  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...    24 kB
# 1  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   870 kB
# 2  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   856 kB
# 3  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   781 kB
# 4  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   748 kB
#
#               FileModifyDate             FileAccessDate  \
# 0  2020:09:01 22:51:09-06:00  2020:09:01 22:51:09-06:00
# 1  2019:08:02 21:50:37-06:00  2019:08:02 21:50:37-06:00
# 2  2019:08:02 21:50:37-06:00  2019:08:02 21:50:37-06:00
# 3  2019:08:02 21:50:38-06:00  2019:08:02 21:50:38-06:00
# 4  2019:08:02 21:50:38-06:00  2019:08:02 21:50:38-06:00
#
#          FileInodeChangeDate FilePermissions FileType FileTypeExtension  \
# 0  2020:09:01 22:51:09-06:00       rwxrwxrwx     JPEG               jpg
# 1  2019:08:02 21:50:37-06:00       rwxrwxrwx     JPEG               jpg
# 2  2019:08:02 21:50:37-06:00       rwxrwxrwx     JPEG               jpg
# 3  2019:08:02 21:50:38-06:00       rwxrwxrwx     JPEG               jpg
# 4  2019:08:02 21:50:38-06:00       rwxrwxrwx     JPEG               jpg
#
#      MIMEType              ExifByteOrder     Make           Model  \
# 0  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 1  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 2  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 3  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 4  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
#
#    XResolution  YResolution ResolutionUnit           ModifyDate  \
# 0           72           72         inches  2019:12:11 09:28:36
# 1           72           72         inches  2019:03:28 16:00:00
# 2           72           72         inches  2019:03:28 17:00:00
# 3           72           72         inches  2019:03:28 18:00:00
# 4           72           72         inches  2019:03:28 19:00:00
#
#   YCbCrPositioning ExposureTime  ISO  ExifVersion     DateTimeOriginal  \
# 0         Co-sited            4    0          220  2019:12:11 09:28:36
# 1         Co-sited        1/960  100          220  2019:03:28 16:00:00
# 2         Co-sited        1/436  100          220  2019:03:28 17:00:00
# 3         Co-sited        1/188  100          220  2019:03:28 18:00:00
# 4         Co-sited        1/120  125          220  2019:03:28 19:00:00
#
#             CreateDate  TimeZoneOffset ComponentsConfiguration Flash  \
# 0  2019:12:11 09:28:36               0            Y, Cb, Cr, -   Off
# 1  2019:03:28 16:00:00              -6            Y, Cb, Cr, -   Off
# 2  2019:03:28 17:00:00              -6            Y, Cb, Cr, -   Off
# 3  2019:03:28 18:00:00              -6            Y, Cb, Cr, -   Off
# 4  2019:03:28 19:00:00              -6            Y, Cb, Cr, -   Off
#
#    FileNumber  DirectoryNumber FirmwareVersion FirmwareDate  TriggerMode  \
# 0           1              101            1.4a   2018:08:24  Unknown (C)
# 1          10              100            1.4a   2018:08:24   Time Lapse
# 2          11              100            1.4a   2018:08:24   Time Lapse
# 3          12              100            1.4a   2018:08:24   Time Lapse
# 4          13              100            1.4a   2018:08:24   Time Lapse
#
#   Sequence  EventNumber DayOfWeek     MoonPhase AmbientTemperatureFahrenheit  \
# 0   0 of 0            1  Thursday          Full                         11 F
# 1   0 of 0            1    Friday  Last Quarter                         48 F
# 2   0 of 0            2    Friday  Last Quarter                         46 F
# 3   0 of 0            3    Friday  Last Quarter                         44 F
# 4   0 of 0            4    Friday  Last Quarter                         41 F
#
#   AmbientTemperature  Contrast  Brightness  Sharpness  Saturation  \
# 0              -12 C         0           0          0           0
# 1                9 C       128           0         64         128
# 2                8 C       128           0         64         128
# 3                7 C       128           0         64         128
# 4                5 C       128           0         64         128
#
#    AmbientInfrared  AmbientLight  MotionSensitivity  BatteryVoltage  \
# 0                5            15                 90            8389
# 1             3515         10240                 90            9315
# 2             1875          5643                 90            9315
# 3              816          2648                 90            9315
# 4              389          1382                 90            9297
#
#    BatteryVoltageAvg  BatteryType      UserLabel    SerialNumber  \
# 0               8389            1  EDAL-A04-HOH1  HLPXEL07016990
# 1               9315            1  EDAL-A04-SST3  HLPXEL09018753
# 2               9315            1  EDAL-A04-SST3  HLPXEL09018753
# 3               9315            1  EDAL-A04-SST3  HLPXEL09018753
# 4               9303            1  EDAL-A04-SST3  HLPXEL09018753
#
#    FlashpixVersion ColorSpace  ExifImageWidth  ExifImageHeight ExposureMode  \
# 0              100       sRGB             800              600         Auto
# 1              100       sRGB            2048             1440         Auto
# 2              100       sRGB            2048             1440         Auto
# 3              100       sRGB            2048             1440         Auto
# 4              100       sRGB            2048             1440         Auto
#
#   WhiteBalance SceneCaptureType GPSVersionID GPSLatitudeRef GPSLongitudeRef  \
# 0       Manual         Standard      2.2.0.0     Unknown ()      Unknown ()
# 1       Manual         Standard      2.2.0.0          North            West
# 2       Manual         Standard      2.2.0.0          North            West
# 3       Manual         Standard      2.2.0.0          North            West
# 4       Manual         Standard      2.2.0.0          North            West
#
#           GPSLatitude          GPSLongitude  ImageWidth  ImageHeight  \
# 0    0 deg 0' 0.00" N      0 deg 0' 0.00" E         800          600
# 1  53 deg 40' 3.36" N  113 deg 17' 26.52" W        2048         1440
# 2  53 deg 40' 3.36" N  113 deg 17' 26.52" W        2048         1440
# 3  53 deg 40' 3.36" N  113 deg 17' 26.52" W        2048         1440
# 4  53 deg 40' 3.36" N  113 deg 17' 26.52" W        2048         1440
#
#                 EncodingProcess  BitsPerSample  ColorComponents  \
# 0  Baseline DCT, Huffman coding              8                3
# 1  Baseline DCT, Huffman coding              8                3
# 2  Baseline DCT, Huffman coding              8                3
# 3  Baseline DCT, Huffman coding              8                3
# 4  Baseline DCT, Huffman coding              8                3
#
#    YCbCrSubSampling  ImageSize  Megapixels ShutterSpeed  \
# 0  YCbCr4:2:2 (2 1)    800x600        0.48            4
# 1  YCbCr4:2:2 (2 1)  2048x1440        2.90        1/960
# 2  YCbCr4:2:2 (2 1)  2048x1440        2.90        1/436
# 3  YCbCr4:2:2 (2 1)  2048x1440        2.90        1/188
# 4  YCbCr4:2:2 (2 1)  2048x1440        2.90        1/120
#
#                                 GPSPosition  image_number
# 0        0 deg 0' 0.00" N, 0 deg 0' 0.00" E           490
# 1  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            10
# 2  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            11
# 3  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            12
# 4  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            13

# %%
df_HC600_HYPERFIRE['CreateDate'] = pd.to_datetime(df_HC600_HYPERFIRE['CreateDate'], format='%Y:%m:%d %H:%M:%S')

# %%
df_HC600_HYPERFIRE['file'] = df_HC600_HYPERFIRE['SourceFile'].apply(lambda x: '/'.join(x.split('/')[4:]))

# %%
df_HC600_HYPERFIRE.head()
# Out:
#                                           SourceFile  ExifToolVersion  \
# 0  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 1  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 2  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 3  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 4  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
#
#                       FileName  \
# 0  EDALA04HOH1_D8_RCNX0490.JPG
# 1  EDALA04SST3_D1_RCNX0010.JPG
# 2  EDALA04SST3_D1_RCNX0011.JPG
# 3  EDALA04SST3_D1_RCNX0012.JPG
# 4  EDALA04SST3_D1_RCNX0013.JPG
#
#                                            Directory FileSize  \
# 0  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...    24 kB
# 1  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   870 kB
# 2  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   856 kB
# 3  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   781 kB
# 4  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   748 kB
#
#               FileModifyDate             FileAccessDate  \
# 0  2020:09:01 22:51:09-06:00  2020:09:01 22:51:09-06:00
# 1  2019:08:02 21:50:37-06:00  2019:08:02 21:50:37-06:00
# 2  2019:08:02 21:50:37-06:00  2019:08:02 21:50:37-06:00
# 3  2019:08:02 21:50:38-06:00  2019:08:02 21:50:38-06:00
# 4  2019:08:02 21:50:38-06:00  2019:08:02 21:50:38-06:00
#
#          FileInodeChangeDate FilePermissions FileType FileTypeExtension  \
# 0  2020:09:01 22:51:09-06:00       rwxrwxrwx     JPEG               jpg
# 1  2019:08:02 21:50:37-06:00       rwxrwxrwx     JPEG               jpg
# 2  2019:08:02 21:50:37-06:00       rwxrwxrwx     JPEG               jpg
# 3  2019:08:02 21:50:38-06:00       rwxrwxrwx     JPEG               jpg
# 4  2019:08:02 21:50:38-06:00       rwxrwxrwx     JPEG               jpg
#
#      MIMEType              ExifByteOrder     Make           Model  \
# 0  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 1  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 2  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 3  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 4  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
#
#    XResolution  YResolution ResolutionUnit           ModifyDate  \
# 0           72           72         inches  2019:12:11 09:28:36
# 1           72           72         inches  2019:03:28 16:00:00
# 2           72           72         inches  2019:03:28 17:00:00
# 3           72           72         inches  2019:03:28 18:00:00
# 4           72           72         inches  2019:03:28 19:00:00
#
#   YCbCrPositioning ExposureTime  ISO  ExifVersion     DateTimeOriginal  \
# 0         Co-sited            4    0          220  2019:12:11 09:28:36
# 1         Co-sited        1/960  100          220  2019:03:28 16:00:00
# 2         Co-sited        1/436  100          220  2019:03:28 17:00:00
# 3         Co-sited        1/188  100          220  2019:03:28 18:00:00
# 4         Co-sited        1/120  125          220  2019:03:28 19:00:00
#
#            CreateDate  TimeZoneOffset ComponentsConfiguration Flash  \
# 0 2019-12-11 09:28:36               0            Y, Cb, Cr, -   Off
# 1 2019-03-28 16:00:00              -6            Y, Cb, Cr, -   Off
# 2 2019-03-28 17:00:00              -6            Y, Cb, Cr, -   Off
# 3 2019-03-28 18:00:00              -6            Y, Cb, Cr, -   Off
# 4 2019-03-28 19:00:00              -6            Y, Cb, Cr, -   Off
#
#    FileNumber  DirectoryNumber FirmwareVersion FirmwareDate  TriggerMode  \
# 0           1              101            1.4a   2018:08:24  Unknown (C)
# 1          10              100            1.4a   2018:08:24   Time Lapse
# 2          11              100            1.4a   2018:08:24   Time Lapse
# 3          12              100            1.4a   2018:08:24   Time Lapse
# 4          13              100            1.4a   2018:08:24   Time Lapse
#
#   Sequence  EventNumber DayOfWeek     MoonPhase AmbientTemperatureFahrenheit  \
# 0   0 of 0            1  Thursday          Full                         11 F
# 1   0 of 0            1    Friday  Last Quarter                         48 F
# 2   0 of 0            2    Friday  Last Quarter                         46 F
# 3   0 of 0            3    Friday  Last Quarter                         44 F
# 4   0 of 0            4    Friday  Last Quarter                         41 F
#
#   AmbientTemperature  Contrast  Brightness  Sharpness  Saturation  \
# 0              -12 C         0           0          0           0
# 1                9 C       128           0         64         128
# 2                8 C       128           0         64         128
# 3                7 C       128           0         64         128
# 4                5 C       128           0         64         128
#
#    AmbientInfrared  AmbientLight  MotionSensitivity  BatteryVoltage  \
# 0                5            15                 90            8389
# 1             3515         10240                 90            9315
# 2             1875          5643                 90            9315
# 3              816          2648                 90            9315
# 4              389          1382                 90            9297
#
#    BatteryVoltageAvg  BatteryType      UserLabel    SerialNumber  \
# 0               8389            1  EDAL-A04-HOH1  HLPXEL07016990
# 1               9315            1  EDAL-A04-SST3  HLPXEL09018753
# 2               9315            1  EDAL-A04-SST3  HLPXEL09018753
# 3               9315            1  EDAL-A04-SST3  HLPXEL09018753
# 4               9303            1  EDAL-A04-SST3  HLPXEL09018753
#
#    FlashpixVersion ColorSpace  ExifImageWidth  ExifImageHeight ExposureMode  \
# 0              100       sRGB             800              600         Auto
# 1              100       sRGB            2048             1440         Auto
# 2              100       sRGB            2048             1440         Auto
# 3              100       sRGB            2048             1440         Auto
# 4              100       sRGB            2048             1440         Auto
#
#   WhiteBalance SceneCaptureType GPSVersionID GPSLatitudeRef GPSLongitudeRef  \
# 0       Manual         Standard      2.2.0.0     Unknown ()      Unknown ()
# 1       Manual         Standard      2.2.0.0          North            West
# 2       Manual         Standard      2.2.0.0          North            West
# 3       Manual         Standard      2.2.0.0          North            West
# 4       Manual         Standard      2.2.0.0          North            West
#
#           GPSLatitude          GPSLongitude  ImageWidth  ImageHeight  \
# 0    0 deg 0' 0.00" N      0 deg 0' 0.00" E         800          600
# 1  53 deg 40' 3.36" N  113 deg 17' 26.52" W        2048         1440
# 2  53 deg 40' 3.36" N  113 deg 17' 26.52" W        2048         1440
# 3  53 deg 40' 3.36" N  113 deg 17' 26.52" W        2048         1440
# 4  53 deg 40' 3.36" N  113 deg 17' 26.52" W        2048         1440
#
#                 EncodingProcess  BitsPerSample  ColorComponents  \
# 0  Baseline DCT, Huffman coding              8                3
# 1  Baseline DCT, Huffman coding              8                3
# 2  Baseline DCT, Huffman coding              8                3
# 3  Baseline DCT, Huffman coding              8                3
# 4  Baseline DCT, Huffman coding              8                3
#
#    YCbCrSubSampling  ImageSize  Megapixels ShutterSpeed  \
# 0  YCbCr4:2:2 (2 1)    800x600        0.48            4
# 1  YCbCr4:2:2 (2 1)  2048x1440        2.90        1/960
# 2  YCbCr4:2:2 (2 1)  2048x1440        2.90        1/436
# 3  YCbCr4:2:2 (2 1)  2048x1440        2.90        1/188
# 4  YCbCr4:2:2 (2 1)  2048x1440        2.90        1/120
#
#                                 GPSPosition  image_number  \
# 0        0 deg 0' 0.00" N, 0 deg 0' 0.00" E           490
# 1  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            10
# 2  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            11
# 3  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            12
# 4  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            13
#
#                                                 file
# 0  EDAL-A04-HOH1 (Horse hill 1)/SD#8 (SEP 30, 201...
# 1  EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2...
# 2  EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2...
# 3  EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2...
# 4  EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2...

# %%
df_ai_results.head()
# Out:
#                                                 file  max_detection_conf  \
# 0  BEHA-B02-DEN1 (Behavioural den #1)/SD#1 (JUN 2...               0.146
# 1  BEHA-B02-DEN1 (Behavioural den #1)/SD#1 (JUN 2...               0.415
# 2  BEHA-B02-DEN1 (Behavioural den #1)/SD#1 (JUN 2...               0.447
# 3  BEHA-B02-DEN1 (Behavioural den #1)/SD#1 (JUN 2...               0.964
# 4  BEHA-B02-DEN1 (Behavioural den #1)/SD#1 (JUN 2...               0.994
#
#                                           detections failure  person  animal  \
# 0  [{'category': '1', 'conf': 0.146, 'bbox': [0.9...     NaN       0       1
# 1  [{'category': '1', 'conf': 0.415, 'bbox': [0.9...     NaN       0       1
# 2  [{'category': '1', 'conf': 0.447, 'bbox': [0.9...     NaN       0       1
# 3  [{'category': '1', 'conf': 0.964, 'bbox': [0.7...     NaN       1       1
# 4  [{'category': '2', 'conf': 0.994, 'bbox': [0.6...     NaN       1       0
#
#    vehicle  empty  person_maxConf  animal_maxConf  vehicle_maxConf
# 0        0      0           0.000           0.146              0.0
# 1        0      0           0.000           0.415              0.0
# 2        0      0           0.000           0.447              0.0
# 3        0      0           0.398           0.964              0.0
# 4        0      0           0.994           0.000              0.0

# %%
df_ai_w_metadta = df_HC600_HYPERFIRE.merge(df_ai_results, left_on='file', right_on='file', how='inner')

# %%
len(df_ai_w_metadta)
# Out:
# 31411

# %%
print(len(df_ai_w_metadta[df_ai_w_metadta['person_maxConf'] >= 0.5]))

len(df_ai_w_metadta[df_ai_w_metadta['person_maxConf'] < 0.5])
# Out:
# 1492
# 29919

# %% [markdown]
# # Remove non-trigerred images

# %%
df_ai_w_metadta.groupby('Sequence').size()
# Out:
# Sequence
# 0 of 0    20277
# 1 of 3     3712
# 2 of 3     3712
# 3 of 3     3710
# dtype: int64

# %%
df_ai_w_metadta = df_ai_w_metadta[df_ai_w_metadta['Sequence'] != '0 of 0']

# %%
df_ai_w_metadta.groupby('Sequence').size()
# Out:
# Sequence
# 1 of 3    3712
# 2 of 3    3712
# 3 of 3    3710
# dtype: int64

# %% [markdown]
# ## Remove human images with confidence >= 0.5

# %%
# df_ai_w_metadta['person_maxConf'].plot()

df_ai_w_metadta.groupby('person_maxConf').size().plot()

# %%
df_ai_w_metadta_nohuman = df_ai_w_metadta[
    (df_ai_w_metadta['person_maxConf'] < 0.5)]

# %%
df_ai_w_metadta_nohuman.head()
# Out:
#                                           SourceFile  ExifToolVersion  \
# 5  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 6  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 7  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 8  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 9  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
#
#                       FileName  \
# 5  EDALA04SST3_D1_RCNX0014.JPG
# 6  EDALA04SST3_D1_RCNX0015.JPG
# 7  EDALA04SST3_D1_RCNX0016.JPG
# 8  EDALA04SST3_D1_RCNX0017.JPG
# 9  EDALA04SST3_D1_RCNX0018.JPG
#
#                                            Directory FileSize  \
# 5  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   742 kB
# 6  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   705 kB
# 7  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   699 kB
# 8  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   792 kB
# 9  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   791 kB
#
#               FileModifyDate             FileAccessDate  \
# 5  2019:08:02 21:50:38-06:00  2019:08:02 21:50:38-06:00
# 6  2019:08:02 21:50:38-06:00  2019:08:02 21:50:38-06:00
# 7  2019:08:02 21:50:38-06:00  2019:08:02 21:50:38-06:00
# 8  2019:08:02 21:50:38-06:00  2019:08:02 21:50:38-06:00
# 9  2019:08:02 21:50:38-06:00  2019:08:02 21:50:38-06:00
#
#          FileInodeChangeDate FilePermissions FileType FileTypeExtension  \
# 5  2019:08:02 21:50:38-06:00       rwxrwxrwx     JPEG               jpg
# 6  2019:08:02 21:50:38-06:00       rwxrwxrwx     JPEG               jpg
# 7  2019:08:02 21:50:38-06:00       rwxrwxrwx     JPEG               jpg
# 8  2019:08:02 21:50:38-06:00       rwxrwxrwx     JPEG               jpg
# 9  2019:08:02 21:50:38-06:00       rwxrwxrwx     JPEG               jpg
#
#      MIMEType              ExifByteOrder     Make           Model  \
# 5  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 6  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 7  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 8  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 9  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
#
#    XResolution  YResolution ResolutionUnit           ModifyDate  \
# 5           72           72         inches  2019:03:28 19:59:16
# 6           72           72         inches  2019:03:28 19:59:18
# 7           72           72         inches  2019:03:28 19:59:18
# 8           72           72         inches  2019:03:28 20:00:41
# 9           72           72         inches  2019:03:28 20:00:42
#
#   YCbCrPositioning ExposureTime  ISO  ExifVersion     DateTimeOriginal  \
# 5         Co-sited         1/39  400          220  2019:03:28 19:59:16
# 6         Co-sited         1/39  400          220  2019:03:28 19:59:18
# 7         Co-sited         1/30  400          220  2019:03:28 19:59:18
# 8         Co-sited         1/37  400          220  2019:03:28 20:00:41
# 9         Co-sited         1/37  400          220  2019:03:28 20:00:42
#
#            CreateDate  TimeZoneOffset ComponentsConfiguration Flash  \
# 5 2019-03-28 19:59:16              -6            Y, Cb, Cr, -   Off
# 6 2019-03-28 19:59:18              -6            Y, Cb, Cr, -   Off
# 7 2019-03-28 19:59:18              -6            Y, Cb, Cr, -   Off
# 8 2019-03-28 20:00:41              -6            Y, Cb, Cr, -   Off
# 9 2019-03-28 20:00:42              -6            Y, Cb, Cr, -   Off
#
#    FileNumber  DirectoryNumber FirmwareVersion FirmwareDate       TriggerMode  \
# 5          14              100            1.4a   2018:08:24  Motion Detection
# 6          15              100            1.4a   2018:08:24  Motion Detection
# 7          16              100            1.4a   2018:08:24  Motion Detection
# 8          17              100            1.4a   2018:08:24  Motion Detection
# 9          18              100            1.4a   2018:08:24  Motion Detection
#
#   Sequence  EventNumber DayOfWeek     MoonPhase AmbientTemperatureFahrenheit  \
# 5   1 of 3            4    Friday  Last Quarter                         37 F
# 6   2 of 3            4    Friday  Last Quarter                         37 F
# 7   3 of 3            4    Friday  Last Quarter                         37 F
# 8   1 of 3            5    Friday  Last Quarter                         37 F
# 9   2 of 3            5    Friday  Last Quarter                         37 F
#
#   AmbientTemperature  Contrast  Brightness  Sharpness  Saturation  \
# 5                3 C       128           0         64         128
# 6                3 C       128           0         64         128
# 7                3 C       128           0         64         128
# 8                3 C       128           0         64         128
# 9                3 C       128           0         64         128
#
#    AmbientInfrared  AmbientLight  MotionSensitivity  BatteryVoltage  \
# 5               72           213                 90            9263
# 6               72           213                 90            9263
# 7               72           213                 90            9246
# 8               66           193                 90            9223
# 9               66           193                 90            9223
#
#    BatteryVoltageAvg  BatteryType      UserLabel    SerialNumber  \
# 5               9284            1  EDAL-A04-SST3  HLPXEL09018753
# 6               9284            1  EDAL-A04-SST3  HLPXEL09018753
# 7               9284            1  EDAL-A04-SST3  HLPXEL09018753
# 8               9264            1  EDAL-A04-SST3  HLPXEL09018753
# 9               9264            1  EDAL-A04-SST3  HLPXEL09018753
#
#    FlashpixVersion ColorSpace  ExifImageWidth  ExifImageHeight ExposureMode  \
# 5              100       sRGB            2048             1440         Auto
# 6              100       sRGB            2048             1440         Auto
# 7              100       sRGB            2048             1440         Auto
# 8              100       sRGB            2048             1440         Auto
# 9              100       sRGB            2048             1440         Auto
#
#   WhiteBalance SceneCaptureType GPSVersionID GPSLatitudeRef GPSLongitudeRef  \
# 5       Manual         Standard      2.2.0.0          North            West
# 6       Manual         Standard      2.2.0.0          North            West
# 7       Manual         Standard      2.2.0.0          North            West
# 8       Manual         Standard      2.2.0.0          North            West
# 9       Manual         Standard      2.2.0.0          North            West
#
#           GPSLatitude          GPSLongitude  ImageWidth  ImageHeight  \
# 5  53 deg 40' 3.36" N  113 deg 17' 26.52" W        2048         1440
# 6  53 deg 40' 3.36" N  113 deg 17' 26.52" W        2048         1440
# 7  53 deg 40' 3.36" N  113 deg 17' 26.52" W        2048         1440
# 8  53 deg 40' 3.36" N  113 deg 17' 26.52" W        2048         1440
# 9  53 deg 40' 3.36" N  113 deg 17' 26.52" W        2048         1440
#
#                 EncodingProcess  BitsPerSample  ColorComponents  \
# 5  Baseline DCT, Huffman coding              8                3
# 6  Baseline DCT, Huffman coding              8                3
# 7  Baseline DCT, Huffman coding              8                3
# 8  Baseline DCT, Huffman coding              8                3
# 9  Baseline DCT, Huffman coding              8                3
#
#    YCbCrSubSampling  ImageSize  Megapixels ShutterSpeed  \
# 5  YCbCr4:2:2 (2 1)  2048x1440         2.9         1/39
# 6  YCbCr4:2:2 (2 1)  2048x1440         2.9         1/39
# 7  YCbCr4:2:2 (2 1)  2048x1440         2.9         1/30
# 8  YCbCr4:2:2 (2 1)  2048x1440         2.9         1/37
# 9  YCbCr4:2:2 (2 1)  2048x1440         2.9         1/37
#
#                                 GPSPosition  image_number  \
# 5  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            14
# 6  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            15
# 7  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            16
# 8  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            17
# 9  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            18
#
#                                                 file  max_detection_conf  \
# 5  EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2...               0.999
# 6  EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2...               0.999
# 7  EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2...               0.999
# 8  EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2...               0.231
# 9  EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2...               0.202
#
#                                           detections failure  person  animal  \
# 5  [{'category': '1', 'conf': 0.999, 'bbox': [0.5...     NaN       0       1
# 6  [{'category': '1', 'conf': 0.999, 'bbox': [0.3...     NaN       0       1
# 7  [{'category': '1', 'conf': 0.999, 'bbox': [0.1...     NaN       0       1
# 8  [{'category': '1', 'conf': 0.231, 'bbox': [0.2...     NaN       0       1
# 9  [{'category': '1', 'conf': 0.202, 'bbox': [0.2...     NaN       0       1
#
#    vehicle  empty  person_maxConf  animal_maxConf  vehicle_maxConf
# 5        0      0             0.0           0.999              0.0
# 6        0      0             0.0           0.999              0.0
# 7        0      0             0.0           0.999              0.0
# 8        0      0             0.0           0.231              0.0
# 9        0      0             0.0           0.202              0.0

# %%
df_ai_w_metadta[df_ai_w_metadta.Sequence == '1 of 3'].head()
# Out:
#                                            SourceFile  ExifToolVersion  \
# 5   /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 8   /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 11  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 14  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 17  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
#
#                        FileName  \
# 5   EDALA04SST3_D1_RCNX0014.JPG
# 8   EDALA04SST3_D1_RCNX0017.JPG
# 11  EDALA04SST3_D1_RCNX0020.JPG
# 14  EDALA04SST3_D1_RCNX0023.JPG
# 17  EDALA04SST3_D1_RCNX0026.JPG
#
#                                             Directory FileSize  \
# 5   /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   742 kB
# 8   /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   792 kB
# 11  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   748 kB
# 14  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   781 kB
# 17  /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   793 kB
#
#                FileModifyDate             FileAccessDate  \
# 5   2019:08:02 21:50:38-06:00  2019:08:02 21:50:38-06:00
# 8   2019:08:02 21:50:38-06:00  2019:08:02 21:50:38-06:00
# 11  2019:08:02 21:50:38-06:00  2019:08:02 21:50:38-06:00
# 14  2019:08:02 21:50:38-06:00  2019:08:02 21:50:38-06:00
# 17  2019:08:02 21:50:38-06:00  2019:08:02 21:50:38-06:00
#
#           FileInodeChangeDate FilePermissions FileType FileTypeExtension  \
# 5   2019:08:02 21:50:38-06:00       rwxrwxrwx     JPEG               jpg
# 8   2019:08:02 21:50:38-06:00       rwxrwxrwx     JPEG               jpg
# 11  2019:08:02 21:50:38-06:00       rwxrwxrwx     JPEG               jpg
# 14  2019:08:02 21:50:38-06:00       rwxrwxrwx     JPEG               jpg
# 17  2019:08:02 21:50:38-06:00       rwxrwxrwx     JPEG               jpg
#
#       MIMEType              ExifByteOrder     Make           Model  \
# 5   image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 8   image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 11  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 14  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
# 17  image/jpeg  Little-endian (Intel, II)  RECONYX  HF2 PRO COVERT
#
#     XResolution  YResolution ResolutionUnit           ModifyDate  \
# 5            72           72         inches  2019:03:28 19:59:16
# 8            72           72         inches  2019:03:28 20:00:41
# 11           72           72         inches  2019:03:28 20:02:47
# 14           72           72         inches  2019:03:28 20:03:20
# 17           72           72         inches  2019:03:28 20:03:53
#
#    YCbCrPositioning ExposureTime  ISO  ExifVersion     DateTimeOriginal  \
# 5          Co-sited         1/39  400          220  2019:03:28 19:59:16
# 8          Co-sited         1/37  400          220  2019:03:28 20:00:41
# 11         Co-sited         1/30  400          220  2019:03:28 20:02:47
# 14         Co-sited         1/30  500          220  2019:03:28 20:03:20
# 17         Co-sited         1/30  500          220  2019:03:28 20:03:53
#
#             CreateDate  TimeZoneOffset ComponentsConfiguration Flash  \
# 5  2019-03-28 19:59:16              -6            Y, Cb, Cr, -   Off
# 8  2019-03-28 20:00:41              -6            Y, Cb, Cr, -   Off
# 11 2019-03-28 20:02:47              -6            Y, Cb, Cr, -   Off
# 14 2019-03-28 20:03:20              -6            Y, Cb, Cr, -   Off
# 17 2019-03-28 20:03:53              -6            Y, Cb, Cr, -   Off
#
#     FileNumber  DirectoryNumber FirmwareVersion FirmwareDate  \
# 5           14              100            1.4a   2018:08:24
# 8           17              100            1.4a   2018:08:24
# 11          20              100            1.4a   2018:08:24
# 14          23              100            1.4a   2018:08:24
# 17          26              100            1.4a   2018:08:24
#
#          TriggerMode Sequence  EventNumber DayOfWeek     MoonPhase  \
# 5   Motion Detection   1 of 3            4    Friday  Last Quarter
# 8   Motion Detection   1 of 3            5    Friday  Last Quarter
# 11  Motion Detection   1 of 3            6    Friday  Last Quarter
# 14  Motion Detection   1 of 3            7    Friday  Last Quarter
# 17  Motion Detection   1 of 3            8    Friday  Last Quarter
#
#    AmbientTemperatureFahrenheit AmbientTemperature  Contrast  Brightness  \
# 5                          37 F                3 C       128           0
# 8                          37 F                3 C       128           0
# 11                         37 F                3 C       128           0
# 14                         37 F                3 C       128           0
# 17                         37 F                3 C       128           0
#
#     Sharpness  Saturation  AmbientInfrared  AmbientLight  MotionSensitivity  \
# 5          64         128               72           213                 90
# 8          64         128               66           193                 90
# 11         64         128               54           157                 90
# 14         64         128               52           151                 90
# 17         64         128               52           148                 90
#
#     BatteryVoltage  BatteryVoltageAvg  BatteryType      UserLabel  \
# 5             9263               9284            1  EDAL-A04-SST3
# 8             9223               9264            1  EDAL-A04-SST3
# 11            9205               9255            1  EDAL-A04-SST3
# 14            9171               9243            1  EDAL-A04-SST3
# 17            9148               9231            1  EDAL-A04-SST3
#
#       SerialNumber  FlashpixVersion ColorSpace  ExifImageWidth  \
# 5   HLPXEL09018753              100       sRGB            2048
# 8   HLPXEL09018753              100       sRGB            2048
# 11  HLPXEL09018753              100       sRGB            2048
# 14  HLPXEL09018753              100       sRGB            2048
# 17  HLPXEL09018753              100       sRGB            2048
#
#     ExifImageHeight ExposureMode WhiteBalance SceneCaptureType GPSVersionID  \
# 5              1440         Auto       Manual         Standard      2.2.0.0
# 8              1440         Auto       Manual         Standard      2.2.0.0
# 11             1440         Auto       Manual         Standard      2.2.0.0
# 14             1440         Auto       Manual         Standard      2.2.0.0
# 17             1440         Auto       Manual         Standard      2.2.0.0
#
#    GPSLatitudeRef GPSLongitudeRef         GPSLatitude          GPSLongitude  \
# 5           North            West  53 deg 40' 3.36" N  113 deg 17' 26.52" W
# 8           North            West  53 deg 40' 3.36" N  113 deg 17' 26.52" W
# 11          North            West  53 deg 40' 3.36" N  113 deg 17' 26.52" W
# 14          North            West  53 deg 40' 3.36" N  113 deg 17' 26.52" W
# 17          North            West  53 deg 40' 3.36" N  113 deg 17' 26.52" W
#
#     ImageWidth  ImageHeight               EncodingProcess  BitsPerSample  \
# 5         2048         1440  Baseline DCT, Huffman coding              8
# 8         2048         1440  Baseline DCT, Huffman coding              8
# 11        2048         1440  Baseline DCT, Huffman coding              8
# 14        2048         1440  Baseline DCT, Huffman coding              8
# 17        2048         1440  Baseline DCT, Huffman coding              8
#
#     ColorComponents  YCbCrSubSampling  ImageSize  Megapixels ShutterSpeed  \
# 5                 3  YCbCr4:2:2 (2 1)  2048x1440         2.9         1/39
# 8                 3  YCbCr4:2:2 (2 1)  2048x1440         2.9         1/37
# 11                3  YCbCr4:2:2 (2 1)  2048x1440         2.9         1/30
# 14                3  YCbCr4:2:2 (2 1)  2048x1440         2.9         1/30
# 17                3  YCbCr4:2:2 (2 1)  2048x1440         2.9         1/30
#
#                                  GPSPosition  image_number  \
# 5   53 deg 40' 3.36" N, 113 deg 17' 26.52" W            14
# 8   53 deg 40' 3.36" N, 113 deg 17' 26.52" W            17
# 11  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            20
# 14  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            23
# 17  53 deg 40' 3.36" N, 113 deg 17' 26.52" W            26
#
#                                                  file  max_detection_conf  \
# 5   EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2...               0.999
# 8   EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2...               0.231
# 11  EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2...               0.998
# 14  EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2...               0.999
# 17  EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2...               0.999
#
#                                            detections failure  person  animal  \
# 5   [{'category': '1', 'conf': 0.999, 'bbox': [0.5...     NaN       0       1
# 8   [{'category': '1', 'conf': 0.231, 'bbox': [0.2...     NaN       0       1
# 11  [{'category': '1', 'conf': 0.998, 'bbox': [0.7...     NaN       0       1
# 14  [{'category': '1', 'conf': 0.999, 'bbox': [0.0...     NaN       0       1
# 17  [{'category': '1', 'conf': 0.999, 'bbox': [0.0...     NaN       0       1
#
#     vehicle  empty  person_maxConf  animal_maxConf  vehicle_maxConf
# 5         0      0             0.0           0.999              0.0
# 8         0      0             0.0           0.231              0.0
# 11        0      0             0.0           0.998              0.0
# 14        0      0             0.0           0.999              0.0
# 17        0      0             0.0           0.999              0.0

# %%
df_ai_w_metadta.groupby('Sequence').size()
# Out:
# Sequence
# 1 of 3    3712
# 2 of 3    3712
# 3 of 3    3710
# dtype: int64

# %%
df_ai_w_metadta_nohuman['Sequence'].unique()
# Out:
# array(['1 of 3', '2 of 3', '3 of 3'], dtype=object)

# %%
len(df_ai_w_metadta_nohuman)
# Out:
# 9726

# %% [markdown]
# # Unique Directories

# %%
print(len(df_ai_w_metadta_nohuman['Directory'].unique()))

u = df_ai_w_metadta_nohuman['Directory'].unique()

u[0]
# Out:
# 30
# '/mnt/wildlife/wildlifemontoringprogram/EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2019 - JUN 26, 2019)'

# %%
done = []
total = 0

df_no_human_animal_vehicle_sequence = pd.DataFrame(columns=df_ai_w_metadta_nohuman.columns)

# %%
# df_no_human_animal_vehicle_sequence.head()

for u in df_ai_w_metadta_nohuman['Directory'].unique():
    if u not in done:
        print(u)
        df_hold = df_ai_w_metadta_nohuman[df_ai_w_metadta_nohuman['Directory'] == u]
        df_hold.sort_values(by=['CreateDate', 'Sequence'], inplace=True)
        df_hold.reset_index(drop=True, inplace=True)
        max_index = max(df_hold.index)
        min_index = min(df_hold.index)
        print(len(df_hold))
        total+=len(df_hold)
        print('total: ', total)

        df_hold_2 = pd.DataFrame(columns=df_ai_w_metadta_nohuman.columns)

        for index, row in df_hold.iterrows():
            # check if animal confidence is > 0.5 or vehicle confidence is > 0.5
            if row['animal_maxConf'] > 0.5 or row['vehicle_maxConf'] > 0.5:
                # check the sequence
                if row['Sequence'] == '1 of 3':
                    df_hold_2 = df_hold_2.append(df_hold.loc[index])

                    # check index + 1 exists
                    if index+1 <= max_index:
                        # make sure the next image is the next image in the sequence and numbering
                        if df_hold.loc[index+1]['Sequence'] == '2 of 3' and df_hold.loc[index+1]['image_number'] == row['image_number'] + 1:
                            df_hold_2 = df_hold_2.append(df_hold.loc[index+1])

                    if index+2 <= max_index:
                        if df_hold.loc[index+2]['Sequence'] == '3 of 3' and df_hold.loc[index+2]['image_number'] == row['image_number'] + 2:
                            df_hold_2 = df_hold_2.append(df_hold.loc[index+2])
                elif row['Sequence'] == '2 of 3':
                    if index-1 >= min_index:
                        if df_hold.loc[index-1]['Sequence'] == '1 of 3' and df_hold.loc[index-1]['image_number'] == row['image_number'] - 1:
                            df_hold_2 = df_hold_2.append(df_hold.loc[index-1])

                    df_hold_2 = df_hold_2.append(df_hold.loc[index])

                    if index+1 <= max_index:
                        if df_hold.loc[index+1]['Sequence'] == '3 of 3' and df_hold.loc[index+1]['image_number'] == row['image_number'] + 1:
                            df_hold_2 = df_hold_2.append(df_hold.loc[index+1])
                elif row['Sequence'] == '3 of 3':
                    if index-2 >= min_index:
                        if df_hold.loc[index-2]['Sequence'] == '1 of 3' and df_hold.loc[index-2]['image_number'] == row['image_number'] - 2:
                            df_hold_2 = df_hold_2.append(df_hold.loc[index-2])

                    if index-1 >= min_index:
                        if df_hold.loc[index-1]['Sequence'] == '2 of 3' and df_hold.loc[index-1]['image_number'] == row['image_number'] - 1:
                            df_hold_2 = df_hold_2.append(df_hold.loc[index-1])

                    df_hold_2 = df_hold_2.append(df_hold.loc[index])
                else:
                    df_hold_2 = df_hold_2.append(df_hold.loc[index])
                    
        df_hold_2.drop_duplicates(inplace=True)
        df_no_human_animal_vehicle_sequence = df_no_human_animal_vehicle_sequence.append(df_hold_2)

        done.append(u)
# Out:
# /mnt/wildlife/wildlifemontoringprogram/EDAL-A04-SST3 (South Sturgeon)/SD#1 (MAR 28, 2019 - JUN 26, 2019)
# 337
# total:  337
# -c:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /mnt/wildlife/wildlifemontoringprogram/EDAL-A04-SST3 (South Sturgeon)/SD#2 (JUN 26, 2019 - AUG 06, 2019)
# 37
# total:  374
# /mnt/wildlife/wildlifemontoringprogram/EDAL-A04-SST3 (South Sturgeon)/SD#3 (AUG 06, 2019 - SEP 30, 2019)
# 69
# total:  443
# /mnt/wildlife/wildlifemontoringprogram/EDAL-A04-SST3 (South Sturgeon)/SD#4 (SEP 30, 2019 - DEC 11, 2019)
# 170
# total:  613
# /mnt/wildlife/wildlifemontoringprogram/EDAL-A04-SST3 (South Sturgeon)/SD#5 (DEC 11, 2019 - MAY 29, 2020)
# 968
# total:  1581
# /mnt/wildlife/wildlifemontoringprogram/EDAL-A04-SST3 (South Sturgeon)/SD#6 (MAY 29, 2020 - AUG 03, 2020)
# 68
# total:  1649
# /mnt/wildlife/wildlifemontoringprogram/EDAL-B04-DEC3 (Decoteau 3)/SD#10 (MAY 29, 2020 - AUG 01, 2020)
# 1223
# total:  2872
# /mnt/wildlife/wildlifemontoringprogram/EDAL-B04-DEC3 (Decoteau 3)/SD#4 (MAR 28, 2019 - MAY 21,2019)
# 641
# total:  3513
# /mnt/wildlife/wildlifemontoringprogram/EDAL-B04-DEC3 (Decoteau 3)/SD#5 (MAY 21, 2019 - JUN 25, 2019)
# 601
# total:  4114
# /mnt/wildlife/wildlifemontoringprogram/EDAL-B04-DEC3 (Decoteau 3)/SD#6 (JUN 25, 2019 - AUG 09, 2019)
# 254
# total:  4368
# /mnt/wildlife/wildlifemontoringprogram/EDAL-B04-DEC3 (Decoteau 3)/SD#7 (AUG 09, 2019 - SEP 30, 2019)
# 402
# total:  4770
# /mnt/wildlife/wildlifemontoringprogram/EDAL-B04-DEC3 (Decoteau 3)/SD#8 (SEP 30, 2019 - DEC 12, 2019)
# 501
# total:  5271
# /mnt/wildlife/wildlifemontoringprogram/EDAL-B04-DEC3 (Decoteau 3)/SD#9 (DEC 12, 2019 - MAY 29, 2020)
# 744
# total:  6015
# /mnt/wildlife/wildlifemontoringprogram/EDAL-B04-DEC3 (Deoteau 3)/SD#5 (MAY 21, 2019 - JUN 25, 2019)
# 601
# total:  6616
# /mnt/wildlife/wildlifemontoringprogram/EDAL-C02-WWR1 (Wolf Willow Ravine)/SD#3 (MAR 31, 2019 - JUN 25, 2019)
# 389
# total:  7005
# /mnt/wildlife/wildlifemontoringprogram/EDAL-C02-WWR1 (Wolf Willow Ravine)/SD#4 (JUN 25, 2019 - SEP 30, 2019)
# 149
# total:  7154
# /mnt/wildlife/wildlifemontoringprogram/EDAL-C02-WWR1 (Wolf Willow Ravine)/SD#5 (SEP 30, 2019 - DEC 18, 2019)
# 111
# total:  7265
# /mnt/wildlife/wildlifemontoringprogram/EDAL-C02-WWR1 (Wolf Willow Ravine)/SD#6 (DEC 18, 2019 - APR 22, 2020)
# 393
# total:  7658
# /mnt/wildlife/wildlifemontoringprogram/EDAL-C02-WWR1 (Wolf Willow Ravine)/SD#7 (APR 22, 2020 - AUG 01, 2020)
# 243
# total:  7901
# /mnt/wildlife/wildlifemontoringprogram/EDAL-C04-BIG1 (Big island)/SD#10 (DEC 17, 2019 - MAY 29, 2020)
# 306
# total:  8207
# /mnt/wildlife/wildlifemontoringprogram/EDAL-C04-BIG1 (Big island)/SD#11 (MAY 29, 2020 - AUG 01, 2020)
# 97
# total:  8304
# /mnt/wildlife/wildlifemontoringprogram/EDAL-C04-BIG1 (Big island)/SD#6 (MAR 27, 2019 - JUN 25, 2019)
# 270
# total:  8574
# /mnt/wildlife/wildlifemontoringprogram/EDAL-C04-BIG1 (Big island)/SD#7 (JUN 25, 2019 - AUG 09, 2019)
# 97
# total:  8671
# /mnt/wildlife/wildlifemontoringprogram/EDAL-C04-BIG1 (Big island)/SD#8 (AUG 09, 2019 - SEP 30, 2019)
# 113
# total:  8784
# /mnt/wildlife/wildlifemontoringprogram/EDAL-C04-BIG1 (Big island)/SD#9 (SEP 30, 2019 - DEC 17, 2019)
# 176
# total:  8960
# /mnt/wildlife/wildlifemontoringprogram/EDAL-D03-HAP3 (Hawks Pass 3)/SD#1 (MAR 27, 2019 - JUN 28, 2019)
# 348
# total:  9308
# /mnt/wildlife/wildlifemontoringprogram/EDAL-D03-HAP3 (Hawks Pass 3)/SD#2 (JUN 28, 2019 - AUG 06, 2019)
# 112
# total:  9420
# /mnt/wildlife/wildlifemontoringprogram/EDAL-D03-HAP3 (Hawks Pass 3)/SD#3 (AUG 06, 2019 - SEP 30, 2019)
# 78
# total:  9498
# /mnt/wildlife/wildlifemontoringprogram/EDAL-D03-HAP3 (Hawks Pass 3)/SD#4 (SEP 30, 2019 - DEC 11, 2019)
# 108
# total:  9606
# /mnt/wildlife/wildlifemontoringprogram/EDAL-D03-HAP3 (Hawks Pass 3)/SD#5 (DEC 11, 2019 - FEB 8, 2020)
# 120
# total:  9726

# %%
len(df_no_human_animal_vehicle_sequence)
# Out:
# 6750

# %%
df_no_human_animal_vehicle_sequence[['file', 'FileName', 'Sequence']].to_csv(
    'images_to_transfer_to_nonhuman.csv', mode='a', header=False, index=False)

# %%
# df_no_human_animal_vehicle_sequence.to_csv('no_human_animal_vehicle_sequence.csv', index=False)

# %%
df_no_human_animal_vehicle_sequence[(df_no_human_animal_vehicle_sequence.vehicle_maxConf < 0.5) & 
                                   (df_no_human_animal_vehicle_sequence.animal_maxConf < 0.5)]
# Out:
#                                             SourceFile  ExifToolVersion  \
# 7    /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 8    /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 10   /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 11   /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# 20   /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...            12.05
# ..                                                 ...              ...
# 240  /mnt/wildlife/wildlifemontoringprogram/EDAL-D0...            12.05
# 315  /mnt/wildlife/wildlifemontoringprogram/EDAL-D0...            12.05
# 316  /mnt/wildlife/wildlifemontoringprogram/EDAL-D0...            12.05
# 334  /mnt/wildlife/wildlifemontoringprogram/EDAL-D0...            12.05
# 335  /mnt/wildlife/wildlifemontoringprogram/EDAL-D0...            12.05
#
#                                  FileName  \
# 7             EDALA01FUP1_D1_IMG_0009.JPG
# 8             EDALA01FUP1_D1_IMG_0010.JPG
# 10            EDALA01FUP1_D1_IMG_0013.JPG
# 11            EDALA01FUP1_D1_IMG_0014.JPG
# 20            EDALA01FUP1_D1_IMG_0025.JPG
# ..                                    ...
# 240  EDALD03HAP2_D9_100RECNX_IMG_0543.JPG
# 315  EDALD03HAP2_D9_100RECNX_IMG_0751.JPG
# 316  EDALD03HAP2_D9_100RECNX_IMG_0752.JPG
# 334  EDALD03HAP2_D9_100RECNX_IMG_0780.JPG
# 335  EDALD03HAP2_D9_100RECNX_IMG_0781.JPG
#
#                                              Directory FileSize  \
# 7    /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   626 kB
# 8    /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   627 kB
# 10   /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   631 kB
# 11   /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   631 kB
# 20   /mnt/wildlife/wildlifemontoringprogram/EDAL-A0...   647 kB
# ..                                                 ...      ...
# 240  /mnt/wildlife/wildlifemontoringprogram/EDAL-D0...   270 kB
# 315  /mnt/wildlife/wildlifemontoringprogram/EDAL-D0...   278 kB
# 316  /mnt/wildlife/wildlifemontoringprogram/EDAL-D0...   279 kB
# 334  /mnt/wildlife/wildlifemontoringprogram/EDAL-D0...   238 kB
# 335  /mnt/wildlife/wildlifemontoringprogram/EDAL-D0...   257 kB
#
#                 FileModifyDate             FileAccessDate  \
# 7    2019:08:02 10:46:41-06:00  2019:08:02 10:46:41-06:00
# 8    2019:08:02 10:46:41-06:00  2019:08:02 10:46:41-06:00
# 10   2019:08:02 10:46:41-06:00  2019:08:02 10:46:41-06:00
# 11   2019:08:02 10:46:42-06:00  2019:08:02 10:46:42-06:00
# 20   2019:08:02 10:46:42-06:00  2019:08:02 10:46:42-06:00
# ..                         ...                        ...
# 240  2019:10:22 00:07:08-06:00  2019:10:22 00:07:08-06:00
# 315  2019:10:22 00:07:21-06:00  2019:10:22 00:07:21-06:00
# 316  2019:10:22 00:07:21-06:00  2019:10:22 00:07:21-06:00
# 334  2019:10:22 00:07:22-06:00  2019:10:22 00:07:22-06:00
# 335  2019:10:22 00:07:22-06:00  2019:10:22 00:07:22-06:00
#
#            FileInodeChangeDate FilePermissions FileType FileTypeExtension  \
# 7    2019:08:02 10:46:41-06:00       rwxrwxrwx     JPEG               jpg
# 8    2019:08:02 10:46:41-06:00       rwxrwxrwx     JPEG               jpg
# 10   2019:08:02 10:46:41-06:00       rwxrwxrwx     JPEG               jpg
# 11   2019:08:02 10:46:42-06:00       rwxrwxrwx     JPEG               jpg
# 20   2019:08:02 10:46:42-06:00       rwxrwxrwx     JPEG               jpg
# ..                         ...             ...      ...               ...
# 240  2019:10:22 00:07:08-06:00       rwxrwxrwx     JPEG               jpg
# 315  2019:10:22 00:07:21-06:00       rwxrwxrwx     JPEG               jpg
# 316  2019:10:22 00:07:21-06:00       rwxrwxrwx     JPEG               jpg
# 334  2019:10:22 00:07:22-06:00       rwxrwxrwx     JPEG               jpg
# 335  2019:10:22 00:07:22-06:00       rwxrwxrwx     JPEG               jpg
#
#        MIMEType              ExifByteOrder     Make               Model  \
# 7    image/jpeg  Little-endian (Intel, II)  RECONYX  PC900 PROFESSIONAL
# 8    image/jpeg  Little-endian (Intel, II)  RECONYX  PC900 PROFESSIONAL
# 10   image/jpeg  Little-endian (Intel, II)  RECONYX  PC900 PROFESSIONAL
# 11   image/jpeg  Little-endian (Intel, II)  RECONYX  PC900 PROFESSIONAL
# 20   image/jpeg  Little-endian (Intel, II)  RECONYX  PC900 PROFESSIONAL
# ..          ...                        ...      ...                 ...
# 240  image/jpeg  Little-endian (Intel, II)  RECONYX     HC600 HYPERFIRE
# 315  image/jpeg  Little-endian (Intel, II)  RECONYX     HC600 HYPERFIRE
# 316  image/jpeg  Little-endian (Intel, II)  RECONYX     HC600 HYPERFIRE
# 334  image/jpeg  Little-endian (Intel, II)  RECONYX     HC600 HYPERFIRE
# 335  image/jpeg  Little-endian (Intel, II)  RECONYX     HC600 HYPERFIRE
#
#     XResolution YResolution ResolutionUnit           ModifyDate  \
# 7            72          72         inches  2018:05:22 11:58:02
# 8            72          72         inches  2018:05:22 11:58:03
# 10           72          72         inches  2018:05:22 12:10:49
# 11           72          72         inches  2018:05:22 12:10:50
# 20           72          72         inches  2018:05:22 14:30:52
# ..          ...         ...            ...                  ...
# 240          72          72         inches  2019:08:30 04:46:08
# 315          72          72         inches  2019:09:27 19:26:52
# 316          72          72         inches  2019:09:27 19:26:53
# 334          72          72         inches  2019:09:30 11:34:15
# 335          72          72         inches  2019:09:30 11:34:16
#
#     YCbCrPositioning ExposureTime  ISO ExifVersion     DateTimeOriginal  \
# 7           Co-sited        1/120   80         220  2018:05:22 11:58:02
# 8           Co-sited        1/120   80         220  2018:05:22 11:58:03
# 10          Co-sited        1/120   64         220  2018:05:22 12:10:49
# 11          Co-sited        1/120   64         220  2018:05:22 12:10:50
# 20          Co-sited         1/82  100         220  2018:05:22 14:30:52
# ..               ...          ...  ...         ...                  ...
# 240         Co-sited         1/30  800         220  2019:08:30 04:46:08
# 315         Co-sited         1/30  800         220  2019:09:27 19:26:52
# 316         Co-sited         1/30  800         220  2019:09:27 19:26:53
# 334         Co-sited         1/30  800         220  2019:09:30 11:34:15
# 335         Co-sited         1/30  800         220  2019:09:30 11:34:16
#
#              CreateDate ComponentsConfiguration               Flash  \
# 7   2018-05-22 11:58:02            Y, Cb, Cr, -  Auto, Did not fire
# 8   2018-05-22 11:58:03            Y, Cb, Cr, -  Auto, Did not fire
# 10  2018-05-22 12:10:49            Y, Cb, Cr, -  Auto, Did not fire
# 11  2018-05-22 12:10:50            Y, Cb, Cr, -  Auto, Did not fire
# 20  2018-05-22 14:30:52            Y, Cb, Cr, -  Auto, Did not fire
# ..                  ...                     ...                 ...
# 240 2019-08-30 04:46:08            Y, Cb, Cr, -         Auto, Fired
# 315 2019-09-27 19:26:52            Y, Cb, Cr, -         Auto, Fired
# 316 2019-09-27 19:26:53            Y, Cb, Cr, -         Auto, Fired
# 334 2019-09-30 11:34:15            Y, Cb, Cr, -  Auto, Did not fire
# 335 2019-09-30 11:34:16            Y, Cb, Cr, -  Auto, Did not fire
#
#     MakerNoteVersion FirmwareVersion FirmwareDate       TriggerMode Sequence  \
# 7             0xf101           4.1.0   2014:02:13  Motion Detection   2 of 3
# 8             0xf101           4.1.0   2014:02:13  Motion Detection   3 of 3
# 10            0xf101           4.1.0   2014:02:13  Motion Detection   2 of 3
# 11            0xf101           4.1.0   2014:02:13  Motion Detection   3 of 3
# 20            0xf101           4.1.0   2014:02:13  Motion Detection   3 of 3
# ..               ...             ...          ...               ...      ...
# 240           0xf101           4.2.0   2016:12:29  Motion Detection   3 of 3
# 315           0xf101           4.2.0   2016:12:29  Motion Detection   2 of 3
# 316           0xf101           4.2.0   2016:12:29  Motion Detection   3 of 3
# 334           0xf101           4.2.0   2016:12:29  Motion Detection   2 of 3
# 335           0xf101           4.2.0   2016:12:29  Motion Detection   3 of 3
#
#     EventNumber      MoonPhase AmbientTemperatureFahrenheit  \
# 7             3  First Quarter                         76 F
# 8             3  First Quarter                         76 F
# 10            4  First Quarter                         76 F
# 11            4  First Quarter                         76 F
# 20            7  First Quarter                         80 F
# ..          ...            ...                          ...
# 240         149            New                         53 F
# 315         180            New                         36 F
# 316         180            New                         36 F
# 334         187            New                         37 F
# 335         187            New                         37 F
#
#     AmbientTemperature    SerialNumber Contrast Brightness Sharpness  \
# 7                 24 C  P900HG04178359      128          0        74
# 8                 24 C  P900HG04178359      128          0        74
# 10                24 C  P900HG04178359      128          0        74
# 11                24 C  P900HG04178359      128          0        74
# 20                26 C  P900HG04178359      128          0        74
# ..                 ...             ...      ...        ...       ...
# 240               12 C  H600HK08281269      160          0        32
# 315                2 C  H600HK08281269      160          0        32
# 316                2 C  H600HK08281269      160          0        32
# 334                3 C  H600HK08281269      128          0        64
# 335                3 C  H600HK08281269      128          0        64
#
#     Saturation InfraredIlluminator MotionSensitivity BatteryVoltage  \
# 7          154                 Off               100        10.47 V
# 8          154                 Off               100        10.47 V
# 10         154                 Off               100        10.47 V
# 11         154                 Off               100        10.47 V
# 20         154                 Off               100        10.65 V
# ..         ...                 ...               ...            ...
# 240          0                  On               100         8.07 V
# 315          0                  On               100         7.05 V
# 316          0                  On               100         7.12 V
# 334        154                 Off               100         9.97 V
# 335        154                 Off               100         9.97 V
#
#          UserLabel FlashpixVersion ColorSpace ExifImageWidth ExifImageHeight  \
# 7    EDAL-A01-FUP1             100       sRGB           2048            1536
# 8    EDAL-A01-FUP1             100       sRGB           2048            1536
# 10   EDAL-A01-FUP1             100       sRGB           2048            1536
# 11   EDAL-A01-FUP1             100       sRGB           2048            1536
# 20   EDAL-A01-FUP1             100       sRGB           2048            1536
# ..             ...             ...        ...            ...             ...
# 240  EDAL-D04-HAP2             100       sRGB           1920            1080
# 315  EDAL-D04-HAP2             100       sRGB           1920            1080
# 316  EDAL-D04-HAP2             100       sRGB           1920            1080
# 334  EDAL-D04-HAP2             100       sRGB           1920            1080
# 335  EDAL-D04-HAP2             100       sRGB           1920            1080
#
#     ExposureMode WhiteBalance SceneCaptureType ImageWidth ImageHeight  \
# 7           Auto       Manual         Standard       2048        1536
# 8           Auto       Manual         Standard       2048        1536
# 10          Auto       Manual         Standard       2048        1536
# 11          Auto       Manual         Standard       2048        1536
# 20          Auto       Manual         Standard       2048        1536
# ..           ...          ...              ...        ...         ...
# 240         Auto       Manual            Night       1920        1080
# 315         Auto       Manual            Night       1920        1080
# 316         Auto       Manual            Night       1920        1080
# 334         Auto       Manual         Standard       1920        1080
# 335         Auto       Manual         Standard       1920        1080
#
#                   EncodingProcess BitsPerSample ColorComponents  \
# 7    Baseline DCT, Huffman coding             8               3
# 8    Baseline DCT, Huffman coding             8               3
# 10   Baseline DCT, Huffman coding             8               3
# 11   Baseline DCT, Huffman coding             8               3
# 20   Baseline DCT, Huffman coding             8               3
# ..                            ...           ...             ...
# 240  Baseline DCT, Huffman coding             8               3
# 315  Baseline DCT, Huffman coding             8               3
# 316  Baseline DCT, Huffman coding             8               3
# 334  Baseline DCT, Huffman coding             8               3
# 335  Baseline DCT, Huffman coding             8               3
#
#      YCbCrSubSampling  ImageSize  Megapixels ShutterSpeed image_number  \
# 7    YCbCr4:2:2 (2 1)  2048x1536         3.1        1/120            9
# 8    YCbCr4:2:2 (2 1)  2048x1536         3.1        1/120           10
# 10   YCbCr4:2:2 (2 1)  2048x1536         3.1        1/120           13
# 11   YCbCr4:2:2 (2 1)  2048x1536         3.1        1/120           14
# 20   YCbCr4:2:2 (2 1)  2048x1536         3.1         1/82           25
# ..                ...        ...         ...          ...          ...
# 240  YCbCr4:2:2 (2 1)  1920x1080         2.1         1/30          543
# 315  YCbCr4:2:2 (2 1)  1920x1080         2.1         1/30          751
# 316  YCbCr4:2:2 (2 1)  1920x1080         2.1         1/30          752
# 334  YCbCr4:2:2 (2 1)  1920x1080         2.1         1/30          780
# 335  YCbCr4:2:2 (2 1)  1920x1080         2.1         1/30          781
#
#                                                   file  max_detection_conf  \
# 7    EDAL-A01-FUP1 (Fulton Place)/SD#1 (MAY 22, 201...                 0.0
# 8    EDAL-A01-FUP1 (Fulton Place)/SD#1 (MAY 22, 201...                 0.0
# 10   EDAL-A01-FUP1 (Fulton Place)/SD#1 (MAY 22, 201...                 0.0
# 11   EDAL-A01-FUP1 (Fulton Place)/SD#1 (MAY 22, 201...                 0.0
# 20   EDAL-A01-FUP1 (Fulton Place)/SD#1 (MAY 22, 201...                 0.0
# ..                                                 ...                 ...
# 240  EDAL-D03-HAP2 (Hawks Pass 2)/SD#9 (AUG 06, 201...                 0.0
# 315  EDAL-D03-HAP2 (Hawks Pass 2)/SD#9 (AUG 06, 201...                 0.0
# 316  EDAL-D03-HAP2 (Hawks Pass 2)/SD#9 (AUG 06, 201...                 0.0
# 334  EDAL-D03-HAP2 (Hawks Pass 2)/SD#9 (AUG 06, 201...                 0.0
# 335  EDAL-D03-HAP2 (Hawks Pass 2)/SD#9 (AUG 06, 201...                 0.0
#
#     detections  failure person animal vehicle empty  person_maxConf  \
# 7           []      NaN      0      0       0     1             0.0
# 8           []      NaN      0      0       0     1             0.0
# 10          []      NaN      0      0       0     1             0.0
# 11          []      NaN      0      0       0     1             0.0
# 20          []      NaN      0      0       0     1             0.0
# ..         ...      ...    ...    ...     ...   ...             ...
# 240         []      NaN      0      0       0     1             0.0
# 315         []      NaN      0      0       0     1             0.0
# 316         []      NaN      0      0       0     1             0.0
# 334         []      NaN      0      0       0     1             0.0
# 335         []      NaN      0      0       0     1             0.0
#
#      animal_maxConf  vehicle_maxConf
# 7               0.0              0.0
# 8               0.0              0.0
# 10              0.0              0.0
# 11              0.0              0.0
# 20              0.0              0.0
# ..              ...              ...
# 240             0.0              0.0
# 315             0.0              0.0
# 316             0.0              0.0
# 334             0.0              0.0
# 335             0.0              0.0
#
# [28293 rows x 73 columns]

# %%
df_test = pd.read_csv('images_to_transfer_to_nonhuman.csv')

# %%
df_test.head()
# Out:
#                                                 file  \
# 0  EDAL-A04-HOH1 (Horse hill 1)/SD#4 (SEP 24, 201...
# 1  EDAL-A04-HOH1 (Horse hill 1)/SD#4 (SEP 24, 201...
# 2  EDAL-A04-HOH1 (Horse hill 1)/SD#4 (SEP 24, 201...
# 3  EDAL-A04-HOH1 (Horse hill 1)/SD#4 (SEP 24, 201...
# 4  EDAL-A04-HOH1 (Horse hill 1)/SD#4 (SEP 24, 201...
#
#                                FileName Sequence
# 0  EDALA04HOH1_D4_100MEDIA_HUNT0005.JPG      NaN
# 1  EDALA04HOH1_D4_100MEDIA_HUNT0006.JPG      NaN
# 2  EDALA04HOH1_D4_100MEDIA_HUNT0010.JPG      NaN
# 3  EDALA04HOH1_D4_100MEDIA_HUNT0012.JPG      NaN
# 4  EDALA04HOH1_D4_100MEDIA_HUNT0015.JPG      NaN

# %%
len(df_test)
# Out:
# 202558

# %%
len(df_test.drop_duplicates())
# Out:
# 202558

# %%
file = df_test.file.values

# %%
i = 0
for f in file:
    if f.endswith('.JPG') == False:
        print(f)
    else:
        i+=1

# %%
i
# Out:
# 202558

# %%
df_test[df_test['file'] == 'EDAL-A03-MAO1 (Marquis one)/SD#1 (MAY 24, 2018 - JUN 29, 2018)/EDALA03MAO1_D1_IMG_7678.JPG']
# Out:
#                                                     file  \
# 60176  EDAL-A03-MAO1 (Marquis one)/SD#1 (MAY 24, 2018...
#
#                           FileName Sequence
# 60176  EDALA03MAO1_D1_IMG_7678.JPG   2 of 3
